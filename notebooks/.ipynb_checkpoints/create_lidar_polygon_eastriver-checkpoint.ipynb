# %% [markdown]
# ## Create a polygon around the extent of the lidar study area
# Code adapted from David Shean

# %% [markdown]
# Load a reduced resolution overview for processing
# Assumes overviews have already been generated with `gdaladdo -r gauss`

# %% [markdown]
# ### Load necessary packages

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from astropy.time import Time
from datetime import datetime
import rasterio as rio
from rasterio import features

# %%
# %matplotlib inline

# %% [markdown]
# #### Define a useful function:

# %%
#Add DOY and DOWY column
def add_dowy(df, col=None):
    print("Adding Day of Water Year (DOWY)")
    if col is None:
        df['doy'] = df.index.dayofyear
        df['decyear'] = Time(df.index).decimalyear
    else:
        df['doy'] = pd.to_datetime(df[col]).dt.dayofyear
        df['decyear'] = Time(pd.to_datetime(df[col])).decimalyear
    
    #df['dowy'] = (df['doy'].index - pd.DateOffset(months=9)).dayofyear
    # Sept 30 is doy 273
    df['dowy'] = df['doy'] - 273
    df.loc[df['dowy'] <= 0, 'dowy'] += 365

# %% [markdown]
# #### Load in the lidar data:

# %%
lidar_fn = '../data/east_river_lidar/ASO_50M_SWE_USCOGE_20190407.tif'

# %% [markdown]
# #### Create features from the lidar file:

# %%
# I only have one lidar file, so I pulled this code out of the for loop that was
# written by David Shean in his GrandMesa_analysis notebook.

lidar_feat_list = []
#ovr_scale = 8
dt_fieldnum = 4
src = rio.open(lidar_fn)
a = src.read(1, masked=True)
mask = np.ma.getmaskarray(a).astype(np.uint8) - 1
shapes = features.shapes(mask, mask=mask, transform=src.transform)
geom_list = list(shapes)
dt = os.path.splitext(os.path.split(lidar_fn)[-1])[0].split('_')[dt_fieldnum]
lidar_feat_list.extend([{'properties':{'fn':lidar_fn, 'date':'2019'}, 'geometry':i[0]} for i in geom_list])

# %% [markdown]
# Form these features into a geodataframe:

# %%
#dnr_gdf = gpd.GeoDataFrame.from_features(dnr_feat_list, crs=src.crs)
lidar_gdf = gpd.GeoDataFrame.from_features(lidar_feat_list, crs=src.crs)

# %%
lidar_gdf
# Out:
#                                             geometry  \
# 0  POLYGON ((305139.000 4330251.000, 305139.000 4...
#
#                                                   fn  date
# 0  ../data/east_river_lidar/ASO_50M_SWE_USCOGE_20...  2019

# %%
plt.imshow(a, vmin=0, vmax=1)

# %%
extent = gpd.read_file('../data/east_river_from_ross.json')

# %%
extent
# Out:
#         gage                                               name    basin_area  \
# 0   09034900                 BOBTAIL CREEK NEAR JONES PASS, CO.  1.358455e+07
# 1   09035900         SOUTH FORK OF WILLIAMS FORK NEAR LEAL, CO.  7.256992e+07
# 2   09047700                    KEYSTONE GULCH NEAR DILLON, CO.  2.355506e+07
# 3   09065500     GORE CREEK AT UPPER STATION, NEAR MINTURN, CO.  3.775570e+07
# 4   09066000                 BLACK GORE CREEK NEAR MINTURN, CO.  3.239292e+07
# 5   09066200                      BOOTH CREEK NEAR MINTURN, CO.  1.608865e+07
# 6   09066300                     MIDDLE CREEK NEAR MINTURN, CO.  1.551507e+07
# 7   09081600   CRYSTAL RIVER AB AVALANCHE C, NEAR REDSTONE, CO.  4.329286e+08
# 8   09107000                   TAYLOR RIVER AT TAYLOR PARK, CO.  3.304825e+08
# 9   09110000                        TAYLOR RIVER AT ALMONT, CO.  1.236904e+09
# 10  09112500                           EAST RIVER AT ALMONT CO.  7.488986e+08
# 11  09115500                     TOMICHI CREEK AT SARGENTS, CO.  3.847754e+08
# 12  09119000                     TOMICHI CREEK AT GUNNISON, CO.  2.742709e+09
# 13  09124500                         LAKE FORK AT GATEVIEW, CO.  8.794288e+08
# 14  09132500       NORTH FORK GUNNISON RIVER NEAR SOMERSET, CO.  1.363259e+09
# 15  09146200                UNCOMPAHGRE RIVER NEAR RIDGWAY, CO.  3.844913e+08
# 16  09147500                   UNCOMPAHGRE RIVER AT COLONA, CO.  1.159925e+09
# 17  09165000                      DOLORES RIVER BELOW RICO, CO.  2.735027e+08
# 18  09183500        MILL CREEK AT SHELEY TUNNEL, NEAR MOAB, UT.  6.837569e+07
# 19  09210500  FONTENELLE C NR HERSCHLER RANCH, NR FONTENELLE...  4.000356e+08
# 20  09223000      HAMS FORK BELOW POLE CREEK, NEAR FRONTIER, WY  3.276049e+08
# 21  09239500              YAMPA RIVER AT STEAMBOAT SPRINGS, CO.  1.459772e+09
# 22  09304500                       WHITE RIVER NEAR MEEKER, CO.  1.940581e+09
# 23  09312600  WHITE RIVER BL TABBYUNE C NEAR SOLDIER SUMMIT, UT  1.958000e+08
# 24  09352900                 VALLECITO CREEK NEAR BAYFIELD, CO.  1.877740e+08
# 25  09361500                       ANIMAS RIVER AT DURANGO, CO.  1.837856e+09
#
#     snotel_count                                           geometry
# 0              2  MULTIPOLYGON (((424424.38098 4401584.84068, 42...
# 1              2  MULTIPOLYGON (((420669.68916 4394956.26406, 42...
# 2              3  MULTIPOLYGON (((421429.47179 4379838.75203, 42...
# 3              3  MULTIPOLYGON (((390672.90608 4388220.20206, 39...
# 4              3  MULTIPOLYGON (((391595.48742 4382425.40303, 39...
# 5              3  MULTIPOLYGON (((388913.65312 4391968.06997, 38...
# 6              2  MULTIPOLYGON (((384746.60139 4392300.37202, 38...
# 7              3  MULTIPOLYGON (((294794.29755 4343640.79257, 29...
# 8              7  POLYGON ((365365.69337 4317590.51258, 365587.4...
# 9              3  MULTIPOLYGON (((348635.23618 4322926.93778, 34...
# 10             5  MULTIPOLYGON (((322722.18275 4319575.08710, 32...
# 11             2  MULTIPOLYGON (((377799.73983 4271604.00487, 37...
# 12             1  MULTIPOLYGON (((368098.65196 4282285.74025, 36...
# 13             3  MULTIPOLYGON (((306416.74202 4238179.69917, 30...
# 14             4  MULTIPOLYGON (((287914.42267 4345116.12586, 28...
# 15             5  MULTIPOLYGON (((257046.55135 4226694.18459, 25...
# 16             2  MULTIPOLYGON (((262750.07836 4245254.32146, 26...
# 17             7  MULTIPOLYGON (((208055.69108 4190759.06471, 20...
# 18             3  MULTIPOLYGON (((124353.43168 4274525.96463, 12...
# 19             3  MULTIPOLYGON (((35534.51301 4708946.01168, 355...
# 20             3  MULTIPOLYGON (((21295.68483 4677965.00034, 212...
# 21             5  MULTIPOLYGON (((354532.87467 4487396.42180, 35...
# 22             4  MULTIPOLYGON (((261568.73181 4445708.75738, 26...
# 23             1  MULTIPOLYGON (((-21846.80728 4433661.39720, -2...
# 24             4  MULTIPOLYGON (((279497.47801 4173780.62488, 27...
# 25            11  MULTIPOLYGON (((270174.85735 4200891.10420, 27...

# %%
src.crs
# Out:
# CRS.from_epsg(32613)

# %%
extent = extent.set_crs('epsg:32612', allow_override=True)

# %%
fig, ax = plt.subplots()

plt.imshow(a, vmin=0, vmax=1)
extent[extent['gage']=='09112500'].plot(ax=ax, facecolor='none')
# Out:
# <Axes: >

# %%
lidar_gdf.crs
# Out:
# <Projected CRS: EPSG:32613>
# Name: WGS 84 / UTM zone 13N
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 13N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Remove tiny polygons:

# %%
#remove tiny polygons, if using a crs with units in meters (not degrees)
area_thresh = 1e8
lidar_gdf = lidar_gdf.loc[lidar_gdf.area > area_thresh]

# %%
# if the above area threshold isn't big enough (or doesn't work because of the crs)
#dnr_gdf = dnr_gdf.drop([0,1,2])

# %%
lidar_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Add metadata and formatting to the gdf:

# %%
dnr_gdf['date'] = pd.to_datetime(dnr_gdf['date'])
add_dowy(dnr_gdf, col='date')
dnr_gdf['platform'] = 'WaDNR'
dnr_gdf['acqdate'] = dnr_gdf['date']
dnr_gdf.set_index('date', inplace=True)
# Out:
# Adding Day of Water Year (DOWY)

# %% [markdown]
# #### Save the geodataframe:

# %%
dnr_gdf.to_file('../../data/gm_outline.geojson', driver='GeoJSON')
