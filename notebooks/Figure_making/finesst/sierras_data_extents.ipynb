# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import xarray as xr
import rioxarray as rxr
import rasterio as rio

# %%
# gmba = gpd.read_file('GMBA_Inventory_v2.0_standard_300/GMBA_Inventory_v2.0_standard_300.shp')

# %%
# gmba[gmba['MapName']=='Sierra Nevada'].plot()
# Out:
# <Axes: >

# %%
# sierras = gmba[gmba['MapName']=='Sierra Nevada']

# %%
# sierras.to_file('sierras_polygon_gmba.geojson', driver='GeoJSON')

# %%
# sierras = gpd.read_file('sierras_polygon_gmba.geojson')

# %%
cali = gpd.read_file('cb_2018_us_state_500k/cb_2018_us_state_500k.shp')

# %%
cali.plot()
# Out:
# <Axes: >

# %%
cali
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS  \
# 0       28  01779790  0400000US28    28     MS
# 1       37  01027616  0400000US37    37     NC
# 2       40  01102857  0400000US40    40     OK
# 3       51  01779803  0400000US51    51     VA
# 4       54  01779805  0400000US54    54     WV
# 5       22  01629543  0400000US22    22     LA
# 6       26  01779789  0400000US26    26     MI
# 7       25  00606926  0400000US25    25     MA
# 8       16  01779783  0400000US16    16     ID
# 9       12  00294478  0400000US12    12     FL
# 10      31  01779792  0400000US31    31     NE
# 11      53  01779804  0400000US53    53     WA
# 12      35  00897535  0400000US35    35     NM
# 13      72  01779808  0400000US72    72     PR
# 14      46  01785534  0400000US46    46     SD
# 15      48  01779801  0400000US48    48     TX
# 16      06  01779778  0400000US06    06     CA
# 17      01  01779775  0400000US01    01     AL
# 18      13  01705317  0400000US13    13     GA
# ...

# %%
cali = cali[cali['NAME']=='California']

# %%
cali.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()

cali.plot(ax=ax, facecolor='none', edgecolor='grey')
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.savefig('cali_sierras_outline.jpg', dpi=300)

# %%
fig, ax = plt.subplots()

sierras.plot(facecolor='none', edgecolor='k')
plt.tight_layout()
plt.savefig('sierras_outline.jpg', dpi=300)

# %%
sierras
# Out:
#    GMBA_V2_ID GMBA_V1_ID        MapName                            WikiDataUR  \
# 0       11928    3.03.87  Sierra Nevada  https://www.wikidata.org/wiki/Q26777
#
#       MapUnit  Hier_Lvl                                   Feature  \
# 0  Aggregated         4  Mountain range with well-recognized name
#
#           Area   Perimeter  Elev_Low  ...        Name_ES Name_FR  \
# 0  62250.92447  4084.76608      31.0  ...  Sierra Nevada    None
#
#         Name_PT        Name_RU Name_ZH LocalNames ColorAll ColorBasic  \
# 0  Serra Nevada  Сьерра-Невада   內華達山脈       None        4          0
#
#   Color300                                           geometry
# 0        2  MULTIPOLYGON (((-119.66785 37.03245, -119.6711...
#
# [1 rows x 41 columns]

# %%
sierras.Elev_Low
# Out:
# 0    31.0
# Name: Elev_Low, dtype: float64

# %%
sierras.Elev_High
# Out:
# 0    4386.0
# Name: Elev_High, dtype: float64

# %%
swe = xr.open_dataset('../../../data/reanalysis/re_SWE_Post_03_15_1990_2021.nc')

# %%
swe
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:      (Latitude: 4050, Longitude: 5175, Year: 32)
# Coordinates:
#   * Latitude     (Latitude) float64 32kB 31.0 31.01 31.01 ... 48.99 48.99 49.0
#   * Longitude    (Longitude) float64 41kB -125.0 -125.0 -125.0 ... -102.0 -102.0
#     spatial_ref  int64 8B ...
# Dimensions without coordinates: Year
# Data variables:
#     SWE_Post     (Year, Latitude, Longitude) float32 3GB ...

# %%
sca = xr.open_dataset('../../../data/reanalysis/re_SCA_Post_03_15_1990_2021.nc')

# %%
sca
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:      (Latitude: 4050, Longitude: 5175, Year: 32)
# Coordinates:
#   * Latitude     (Latitude) float64 32kB 31.0 31.01 31.01 ... 48.99 48.99 49.0
#   * Longitude    (Longitude) float64 41kB -125.0 -125.0 -125.0 ... -102.0 -102.0
#     spatial_ref  int64 8B ...
# Dimensions without coordinates: Year
# Data variables:
#     SCA_Post     (Year, Latitude, Longitude) float32 3GB ...

# %%
swe.rio.write_crs('EPSG:4326',inplace = True)
swe = swe.rename({'Latitude':'y','Longitude':'x'})
swe = swe.rio.set_spatial_dims('y','x',inplace=True)

# %%
swe_sierras = swe.rio.clip(sierras.geometry)

# %%
swe_sierras
# Out:
# <xarray.Dataset> Size: 149MB
# Dimensions:      (y: 1267, x: 919, Year: 32)
# Coordinates:
#   * y            (y) float64 10kB 34.82 34.82 34.83 34.83 ... 40.44 40.44 40.45
#   * x            (x) float64 7kB -121.9 -121.9 -121.9 ... -117.9 -117.9 -117.9
#     spatial_ref  int64 8B 0
# Dimensions without coordinates: Year
# Data variables:
#     SWE_Post     (Year, y, x) float32 149MB nan nan nan nan ... nan nan nan nan

# %%
fig, ax = plt.subplots()
swe_sierras.SWE_Post[0].plot(ax=ax, cmap='Blues', label='SWE (m)', vmax=1.5)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/swe_1990.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
swe_sierras.SWE_Post[24].plot(ax=ax, cmap='Blues', label='SWE (m)', vmax=1.5)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/swe_2015.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
swe_sierras.SWE_Post[2].plot(ax=ax, cmap='Blues', label='SWE (m)', vmax=1.5)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/swe_1992.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
swe_sierras.SWE_Post[3].plot(ax=ax, cmap='Blues', label='SWE (m)', vmax=1.5)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/swe_1993.jpeg', dpi=300)

# %%
sca.rio.write_crs('EPSG:4326',inplace = True)
sca = sca.rename({'Latitude':'y','Longitude':'x'})
sca = sca.rio.set_spatial_dims('y','x',inplace=True)

# %%
sca_sierras = sca.rio.clip(sierras.geometry)

# %%
depth_sierras = swe_sierras.SWE_Post / 0.35

# %%
fig, ax = plt.subplots()
depth_sierras[0].plot(ax=ax, cmap='GnBu', vmin=0, vmax=3)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/depth_1990.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
depth_sierras[24].plot(ax=ax, cmap='GnBu', vmin=0, vmax=3)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/depth_2015.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
depth_sierras[2].plot(ax=ax, cmap='GnBu', vmin=0, vmax=3)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/depth_1992.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
depth_sierras[2].plot(ax=ax, cmap='GnBu', vmin=0, vmax=3)
sierras.plot(ax=ax, facecolor='none', edgecolor='white')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/depth_1992_forsampling.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
depth_sierras[3].plot(ax=ax, cmap='GnBu', vmin=0, vmax=3)
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/depth_1993.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
sca_sierras.SCA_Post[0].plot(ax=ax, cmap='YlOrBr')
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/sca_1990.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
sca_sierras.SCA_Post[24].plot(ax=ax, cmap='YlOrBr')
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/sca_2015.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
sca_sierras.SCA_Post[2].plot(ax=ax, cmap='YlOrBr')
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/sca_1992.jpeg', dpi=300)

# %%
fig, ax = plt.subplots()
sca_sierras.SCA_Post[3].plot(ax=ax, cmap='YlOrBr')
sierras.plot(ax=ax, facecolor='none', edgecolor='k')
plt.axis('off')
plt.title('')
plt.tight_layout()
plt.savefig('finesst_figures/sca_1993.jpeg', dpi=300)

# %%
xr.corr(sca_sierras.SCA_Post[0], sca_sierras.SCA_Post[1])
# Out:
# <xarray.DataArray 'SCA_Post' ()> Size: 8B
# array(0.74473685)
# Coordinates:
#     spatial_ref  int64 8B 0
